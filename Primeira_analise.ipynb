# %%
import pandas as pd
import seaborn as srn
import statistics as sts

# %%
df = pd.read_csv("Churn.csv", delimiter=";")
print(df.shape)
df.columns = ["ID", "Score", "Estado", "Genero", "Idade", "Patrimonio", "Saldo", "Produtos", "TemCartaoCredito", "Ativo", "Salario", "Saiu"]
df.head()
# Out:
# (999, 12)
#    ID  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartaoCredito  Ativo     Salario  Saiu
# 0                 1      1  10134888.0     1
# 1                 0      1  11254258.0     0
# 2                 1      0  11393157.0     1
# 3                 0      0   9382663.0     0
# 4                 1      1    790841.0     0

# %%
estado = df.groupby(["Estado"]).size()
estado
estado.plot.bar(color='blue')
# Out:
# <Axes: xlabel='Genero'>

# %%
genero = df.groupby(["Genero"]).size()
print(genero)
genero.plot.bar(color='green')
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64
# <Axes: xlabel='Genero'>

# %%
df["Score"].describe()
srn.boxplot(df["Score"]).set_title("Score")
# Out:
# Text(0.5, 1.0, 'Score')

# %%
srn.distplot(df["Score"]).set_title("Score")
# Out:
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_10840\4189140451.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(df["Score"]).set_title("Score")
# Text(0.5, 1.0, 'Score')

# %%
df["Genero"].describe()
srn.boxplot(df["Genero"]).set_title("Genero")
# Out:
# Text(0.5, 1.0, 'Genero')

# %%
df["Idade"].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(df["Idade"]).set_title("Idade")
# Out:
# Text(0.5, 1.0, 'Idade')

# %%
srn.distplot(df["Idade"]).set_title("Idade")
# Out:
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_10840\3964813792.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(df["Idade"]).set_title("Idade")
# Text(0.5, 1.0, 'Idade')

# %%
df["Saldo"].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: Saldo, dtype: float64

# %%
srn.boxplot(df["Saldo"]).set_title("Saldo")
# Out:
# Text(0.5, 1.0, 'Saldo')

# %%
srn.distplot(df['Saldo']).set_title("Saldo")
# Out:
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_10840\1063204860.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(df['Saldo']).set_title("Saldo")
# Text(0.5, 1.0, 'Saldo')

# %%
df["Salario"].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
srn.distplot(df['Salario']).set_title("Salários")
# Out:
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_10840\3155816771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(df['Salario']).set_title("Salários")
# Text(0.5, 1.0, 'Salários')

# %%
df.isnull().sum()
# Out:
# ID                  0
# Score               0
# Estado              0
# Genero              8
# Idade               0
# Patrimonio          0
# Saldo               0
# Produtos            0
# TemCartaoCredito    0
# Ativo               0
# Salario             7
# Saiu                0
# dtype: int64

# %%
df["Salario"].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
df["Salario"].median()
# Out:
# 8703249.5

# %%
df["Salario"].fillna(df["Salario"].median(), inplace=True)

d
